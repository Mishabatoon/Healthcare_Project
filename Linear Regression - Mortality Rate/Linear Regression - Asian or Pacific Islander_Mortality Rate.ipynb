# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random as rnd
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE

# %%
# Import file
file = "Resources/Mortality_Rate.txt"
df = pd.read_csv(file, encoding="ISO-8859-1", sep='\t')
display(df)
# Out:
#                                                   Notes Leading Cancer Sites  \
# 0                                                   NaN               Breast
# 1                                                   NaN               Breast
# 2                                                   NaN               Breast
# 3                                                   NaN               Breast
# 4                                                   NaN               Breast
# ...                                                 ...                  ...
# 2016  data set. Death rates may differ slightly from...                  NaN
# 2017  4. For the 2005 year, the Census Bureau estima...                  NaN
# 2018  Texas due to Hurricanes Katrina and Rita. CDC ...                  NaN
# 2019  these states, nor are these counts included in...                  NaN
# 2020  population. However, the USCS web site does in...                  NaN
#
#       Leading Cancer Sites Code    State  State Code    Year  Year Code  \
# 0                       26000.0  Alabama         1.0  2000.0     2000.0
# 1                       26000.0  Alabama         1.0  2000.0     2000.0
# 2                       26000.0  Alabama         1.0  2001.0     2001.0
# 3                       26000.0  Alabama         1.0  2001.0     2001.0
# 4                       26000.0  Alabama         1.0  2002.0     2002.0
# ...                         ...      ...         ...     ...        ...
# 2016                        NaN      NaN         NaN     NaN        NaN
# 2017                        NaN      NaN         NaN     NaN        NaN
# 2018                        NaN      NaN         NaN     NaN        NaN
# 2019                        NaN      NaN         NaN     NaN        NaN
# 2020                        NaN      NaN         NaN     NaN        NaN
#
#                            Race Race Code     Sex Sex Code  Deaths  \
# 0     Black or African American    2054-5  Female        F   166.0
# 1                         White    2106-3  Female        F   524.0
# 2     Black or African American    2054-5  Female        F   219.0
# 3                         White    2106-3  Female        F   528.0
# 4     Black or African American    2054-5  Female        F   167.0
# ...                         ...       ...     ...      ...     ...
# 2016                        NaN       NaN     NaN      NaN     NaN
# 2017                        NaN       NaN     NaN      NaN     NaN
# 2018                        NaN       NaN     NaN      NaN     NaN
# 2019                        NaN       NaN     NaN      NaN     NaN
# 2020                        NaN       NaN     NaN      NaN     NaN
#
#       Population  Age-Adjusted Rate
# 0       627439.0               29.7
# 1      1643761.0               25.9
# 2       630901.0               38.7
# 3      1645541.0               25.8
# 4       633374.0               29.2
# ...          ...                ...
# 2016         NaN                NaN
# 2017         NaN                NaN
# 2018         NaN                NaN
# 2019         NaN                NaN
# 2020         NaN                NaN
#
# [2021 rows x 14 columns]

# %%
# Drop all columns without any information
df_dropped = df.drop(columns=['Notes','Leading Cancer Sites Code','Year Code','Sex' ],axis=1)
df_dropped = df_dropped.dropna(how='any')
display(df_dropped)
# Out:
#      Leading Cancer Sites    State  State Code    Year  \
# 0                  Breast  Alabama         1.0  2000.0
# 1                  Breast  Alabama         1.0  2000.0
# 2                  Breast  Alabama         1.0  2001.0
# 3                  Breast  Alabama         1.0  2001.0
# 4                  Breast  Alabama         1.0  2002.0
# ...                   ...      ...         ...     ...
# 1962               Breast  Wyoming        56.0  2014.0
# 1963               Breast  Wyoming        56.0  2015.0
# 1964               Breast  Wyoming        56.0  2016.0
# 1965               Breast  Wyoming        56.0  2017.0
# 1966               Breast  Wyoming        56.0  2018.0
#
#                            Race Race Code Sex Code  Deaths  Population  \
# 0     Black or African American    2054-5        F   166.0    627439.0
# 1                         White    2106-3        F   524.0   1643761.0
# 2     Black or African American    2054-5        F   219.0    630901.0
# 3                         White    2106-3        F   528.0   1645541.0
# 4     Black or African American    2054-5        F   167.0    633374.0
# ...                         ...       ...      ...     ...         ...
# 1962                      White    2106-3        F    50.0    268767.0
# 1963                      White    2106-3        F    68.0    270054.0
# 1964                      White    2106-3        F    68.0    269349.0
# 1965                      White    2106-3        F    56.0    266963.0
# 1966                      White    2106-3        F    70.0    266262.0
#
#       Age-Adjusted Rate
# 0                  29.7
# 1                  25.9
# 2                  38.7
# 3                  25.8
# 4                  29.2
# ...                 ...
# 1962               14.1
# 1963               19.7
# 1964               20.0
# 1965               16.5
# 1966               20.6
#
# [1967 rows x 10 columns]

# %%
df_no_other_race = df_dropped[df_dropped["Race"]!="Other Races and Unknown combined"]
df_no_other_race
# Out:
#      Leading Cancer Sites    State  State Code    Year  \
# 0                  Breast  Alabama         1.0  2000.0
# 1                  Breast  Alabama         1.0  2000.0
# 2                  Breast  Alabama         1.0  2001.0
# 3                  Breast  Alabama         1.0  2001.0
# 4                  Breast  Alabama         1.0  2002.0
# ...                   ...      ...         ...     ...
# 1962               Breast  Wyoming        56.0  2014.0
# 1963               Breast  Wyoming        56.0  2015.0
# 1964               Breast  Wyoming        56.0  2016.0
# 1965               Breast  Wyoming        56.0  2017.0
# 1966               Breast  Wyoming        56.0  2018.0
#
#                            Race Race Code Sex Code  Deaths  Population  \
# 0     Black or African American    2054-5        F   166.0    627439.0
# 1                         White    2106-3        F   524.0   1643761.0
# 2     Black or African American    2054-5        F   219.0    630901.0
# 3                         White    2106-3        F   528.0   1645541.0
# 4     Black or African American    2054-5        F   167.0    633374.0
# ...                         ...       ...      ...     ...         ...
# 1962                      White    2106-3        F    50.0    268767.0
# 1963                      White    2106-3        F    68.0    270054.0
# 1964                      White    2106-3        F    68.0    269349.0
# 1965                      White    2106-3        F    56.0    266963.0
# 1966                      White    2106-3        F    70.0    266262.0
#
#       Age-Adjusted Rate
# 0                  29.7
# 1                  25.9
# 2                  38.7
# 3                  25.8
# 4                  29.2
# ...                 ...
# 1962               14.1
# 1963               19.7
# 1964               20.0
# 1965               16.5
# 1966               20.6
#
# [1967 rows x 10 columns]

# %%
df_clean = df_no_other_race[df_no_other_race["Sex Code"]!="M"]
df_clean
# Out:
#      Leading Cancer Sites    State  State Code    Year  \
# 0                  Breast  Alabama         1.0  2000.0
# 1                  Breast  Alabama         1.0  2000.0
# 2                  Breast  Alabama         1.0  2001.0
# 3                  Breast  Alabama         1.0  2001.0
# 4                  Breast  Alabama         1.0  2002.0
# ...                   ...      ...         ...     ...
# 1962               Breast  Wyoming        56.0  2014.0
# 1963               Breast  Wyoming        56.0  2015.0
# 1964               Breast  Wyoming        56.0  2016.0
# 1965               Breast  Wyoming        56.0  2017.0
# 1966               Breast  Wyoming        56.0  2018.0
#
#                            Race Race Code Sex Code  Deaths  Population  \
# 0     Black or African American    2054-5        F   166.0    627439.0
# 1                         White    2106-3        F   524.0   1643761.0
# 2     Black or African American    2054-5        F   219.0    630901.0
# 3                         White    2106-3        F   528.0   1645541.0
# 4     Black or African American    2054-5        F   167.0    633374.0
# ...                         ...       ...      ...     ...         ...
# 1962                      White    2106-3        F    50.0    268767.0
# 1963                      White    2106-3        F    68.0    270054.0
# 1964                      White    2106-3        F    68.0    269349.0
# 1965                      White    2106-3        F    56.0    266963.0
# 1966                      White    2106-3        F    70.0    266262.0
#
#       Age-Adjusted Rate
# 0                  29.7
# 1                  25.9
# 2                  38.7
# 3                  25.8
# 4                  29.2
# ...                 ...
# 1962               14.1
# 1963               19.7
# 1964               20.0
# 1965               16.5
# 1966               20.6
#
# [1853 rows x 10 columns]

# %%
df_Asian_Pacific = df_clean[df_clean["Race"]=="Asian or Pacific Islander"]
df_Asian_Pacific
# Out:
#      Leading Cancer Sites       State  State Code    Year  \
# 84                 Breast     Arizona         4.0  2012.0
# 96                 Breast     Arizona         4.0  2016.0
# 100                Breast     Arizona         4.0  2017.0
# 103                Breast     Arizona         4.0  2018.0
# 144                Breast  California         6.0  2000.0
# ...                   ...         ...         ...     ...
# 1874               Breast  Washington        53.0  2014.0
# 1877               Breast  Washington        53.0  2015.0
# 1880               Breast  Washington        53.0  2016.0
# 1884               Breast  Washington        53.0  2017.0
# 1887               Breast  Washington        53.0  2018.0
#
#                            Race Race Code Sex Code  Deaths  Population  \
# 84    Asian or Pacific Islander      A-PI        F    16.0    128481.0
# 96    Asian or Pacific Islander      A-PI        F    20.0    151290.0
# 100   Asian or Pacific Islander      A-PI        F    20.0    156190.0
# 103   Asian or Pacific Islander      A-PI        F    25.0    160448.0
# 144   Asian or Pacific Islander      A-PI        F   263.0   2160500.0
# ...                         ...       ...      ...     ...         ...
# 1874  Asian or Pacific Islander      A-PI        F    38.0    362557.0
# 1877  Asian or Pacific Islander      A-PI        F    45.0    378700.0
# 1880  Asian or Pacific Islander      A-PI        F    51.0    395443.0
# 1884  Asian or Pacific Islander      A-PI        F    52.0    414270.0
# 1887  Asian or Pacific Islander      A-PI        F    44.0    431588.0
#
#       Age-Adjusted Rate
# 84                 14.5
# 96                 13.3
# 100                13.1
# 103                16.1
# 144                13.3
# ...                 ...
# 1874               11.1
# 1877               12.7
# 1880               13.0
# 1884               12.7
# 1887                9.9
#
# [211 rows x 10 columns]

# %%
df_AP_clean = df_Asian_Pacific.drop(columns=['Leading Cancer Sites','State','State Code','Year', 'Race Code','Sex Code', 'Age-Adjusted Rate' ],axis=1)
df_AP_clean
# Out:
#                            Race  Deaths  Population
# 84    Asian or Pacific Islander    16.0    128481.0
# 96    Asian or Pacific Islander    20.0    151290.0
# 100   Asian or Pacific Islander    20.0    156190.0
# 103   Asian or Pacific Islander    25.0    160448.0
# 144   Asian or Pacific Islander   263.0   2160500.0
# ...                         ...     ...         ...
# 1874  Asian or Pacific Islander    38.0    362557.0
# 1877  Asian or Pacific Islander    45.0    378700.0
# 1880  Asian or Pacific Islander    51.0    395443.0
# 1884  Asian or Pacific Islander    52.0    414270.0
# 1887  Asian or Pacific Islander    44.0    431588.0
#
# [211 rows x 3 columns]

# %%
df_AP_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 211 entries, 84 to 1887
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Race        211 non-null    object
#  1   Deaths      211 non-null    float64
#  2   Population  211 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 6.6+ KB

# %%
df_AP_clean.dtypes
# Out:
# Race           object
# Deaths        float64
# Population    float64
# dtype: object

# %%
from pathlib import Path
plt.scatter(df_AP_clean.Population, df_AP_clean.Deaths)
plt.xlabel('Population')
plt.ylabel('Deaths')
plt.show()

# %%
X = df_AP_clean.Population.values.reshape(-1, 1)

# %%
X.shape
# Out:
# (211, 1)

# %%
y = df_AP_clean.Deaths

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (211,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.00014403]
# -12.87447850372891
