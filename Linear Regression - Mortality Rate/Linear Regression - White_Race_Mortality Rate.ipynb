# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random as rnd
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE

# %%
# Import file
file = "Resources/Mortality_Rate.txt"
df = pd.read_csv(file, encoding="ISO-8859-1", sep='\t')
display(df)
# Out:
#                                                   Notes Leading Cancer Sites  \
# 0                                                   NaN               Breast
# 1                                                   NaN               Breast
# 2                                                   NaN               Breast
# 3                                                   NaN               Breast
# 4                                                   NaN               Breast
# ...                                                 ...                  ...
# 2016  data set. Death rates may differ slightly from...                  NaN
# 2017  4. For the 2005 year, the Census Bureau estima...                  NaN
# 2018  Texas due to Hurricanes Katrina and Rita. CDC ...                  NaN
# 2019  these states, nor are these counts included in...                  NaN
# 2020  population. However, the USCS web site does in...                  NaN
#
#       Leading Cancer Sites Code    State  State Code    Year  Year Code  \
# 0                       26000.0  Alabama         1.0  2000.0     2000.0
# 1                       26000.0  Alabama         1.0  2000.0     2000.0
# 2                       26000.0  Alabama         1.0  2001.0     2001.0
# 3                       26000.0  Alabama         1.0  2001.0     2001.0
# 4                       26000.0  Alabama         1.0  2002.0     2002.0
# ...                         ...      ...         ...     ...        ...
# 2016                        NaN      NaN         NaN     NaN        NaN
# 2017                        NaN      NaN         NaN     NaN        NaN
# 2018                        NaN      NaN         NaN     NaN        NaN
# 2019                        NaN      NaN         NaN     NaN        NaN
# 2020                        NaN      NaN         NaN     NaN        NaN
#
#                            Race Race Code     Sex Sex Code  Deaths  \
# 0     Black or African American    2054-5  Female        F   166.0
# 1                         White    2106-3  Female        F   524.0
# 2     Black or African American    2054-5  Female        F   219.0
# 3                         White    2106-3  Female        F   528.0
# 4     Black or African American    2054-5  Female        F   167.0
# ...                         ...       ...     ...      ...     ...
# 2016                        NaN       NaN     NaN      NaN     NaN
# 2017                        NaN       NaN     NaN      NaN     NaN
# 2018                        NaN       NaN     NaN      NaN     NaN
# 2019                        NaN       NaN     NaN      NaN     NaN
# 2020                        NaN       NaN     NaN      NaN     NaN
#
#       Population  Age-Adjusted Rate
# 0       627439.0               29.7
# 1      1643761.0               25.9
# 2       630901.0               38.7
# 3      1645541.0               25.8
# 4       633374.0               29.2
# ...          ...                ...
# 2016         NaN                NaN
# 2017         NaN                NaN
# 2018         NaN                NaN
# 2019         NaN                NaN
# 2020         NaN                NaN
#
# [2021 rows x 14 columns]

# %%
# Drop all columns without any information
df_dropped = df.drop(columns=['Notes','Leading Cancer Sites Code','Year Code','Sex' ],axis=1)
df_dropped = df_dropped.dropna(how='any')
display(df_dropped)
# Out:
#      Leading Cancer Sites    State  State Code    Year  \
# 0                  Breast  Alabama         1.0  2000.0
# 1                  Breast  Alabama         1.0  2000.0
# 2                  Breast  Alabama         1.0  2001.0
# 3                  Breast  Alabama         1.0  2001.0
# 4                  Breast  Alabama         1.0  2002.0
# ...                   ...      ...         ...     ...
# 1962               Breast  Wyoming        56.0  2014.0
# 1963               Breast  Wyoming        56.0  2015.0
# 1964               Breast  Wyoming        56.0  2016.0
# 1965               Breast  Wyoming        56.0  2017.0
# 1966               Breast  Wyoming        56.0  2018.0
#
#                            Race Race Code Sex Code  Deaths  Population  \
# 0     Black or African American    2054-5        F   166.0    627439.0
# 1                         White    2106-3        F   524.0   1643761.0
# 2     Black or African American    2054-5        F   219.0    630901.0
# 3                         White    2106-3        F   528.0   1645541.0
# 4     Black or African American    2054-5        F   167.0    633374.0
# ...                         ...       ...      ...     ...         ...
# 1962                      White    2106-3        F    50.0    268767.0
# 1963                      White    2106-3        F    68.0    270054.0
# 1964                      White    2106-3        F    68.0    269349.0
# 1965                      White    2106-3        F    56.0    266963.0
# 1966                      White    2106-3        F    70.0    266262.0
#
#       Age-Adjusted Rate
# 0                  29.7
# 1                  25.9
# 2                  38.7
# 3                  25.8
# 4                  29.2
# ...                 ...
# 1962               14.1
# 1963               19.7
# 1964               20.0
# 1965               16.5
# 1966               20.6
#
# [1967 rows x 10 columns]

# %%
df_no_other_race = df_dropped[df_dropped["Race"]!="Other Races and Unknown combined"]
df_no_other_race
# Out:
#      Leading Cancer Sites    State  State Code    Year  \
# 0                  Breast  Alabama         1.0  2000.0
# 1                  Breast  Alabama         1.0  2000.0
# 2                  Breast  Alabama         1.0  2001.0
# 3                  Breast  Alabama         1.0  2001.0
# 4                  Breast  Alabama         1.0  2002.0
# ...                   ...      ...         ...     ...
# 1962               Breast  Wyoming        56.0  2014.0
# 1963               Breast  Wyoming        56.0  2015.0
# 1964               Breast  Wyoming        56.0  2016.0
# 1965               Breast  Wyoming        56.0  2017.0
# 1966               Breast  Wyoming        56.0  2018.0
#
#                            Race Race Code Sex Code  Deaths  Population  \
# 0     Black or African American    2054-5        F   166.0    627439.0
# 1                         White    2106-3        F   524.0   1643761.0
# 2     Black or African American    2054-5        F   219.0    630901.0
# 3                         White    2106-3        F   528.0   1645541.0
# 4     Black or African American    2054-5        F   167.0    633374.0
# ...                         ...       ...      ...     ...         ...
# 1962                      White    2106-3        F    50.0    268767.0
# 1963                      White    2106-3        F    68.0    270054.0
# 1964                      White    2106-3        F    68.0    269349.0
# 1965                      White    2106-3        F    56.0    266963.0
# 1966                      White    2106-3        F    70.0    266262.0
#
#       Age-Adjusted Rate
# 0                  29.7
# 1                  25.9
# 2                  38.7
# 3                  25.8
# 4                  29.2
# ...                 ...
# 1962               14.1
# 1963               19.7
# 1964               20.0
# 1965               16.5
# 1966               20.6
#
# [1967 rows x 10 columns]

# %%
df_clean = df_no_other_race[df_no_other_race["Sex Code"]!="M"]
df_clean
# Out:
#      Leading Cancer Sites    State  State Code    Year  \
# 0                  Breast  Alabama         1.0  2000.0
# 1                  Breast  Alabama         1.0  2000.0
# 2                  Breast  Alabama         1.0  2001.0
# 3                  Breast  Alabama         1.0  2001.0
# 4                  Breast  Alabama         1.0  2002.0
# ...                   ...      ...         ...     ...
# 1962               Breast  Wyoming        56.0  2014.0
# 1963               Breast  Wyoming        56.0  2015.0
# 1964               Breast  Wyoming        56.0  2016.0
# 1965               Breast  Wyoming        56.0  2017.0
# 1966               Breast  Wyoming        56.0  2018.0
#
#                            Race Race Code Sex Code  Deaths  Population  \
# 0     Black or African American    2054-5        F   166.0    627439.0
# 1                         White    2106-3        F   524.0   1643761.0
# 2     Black or African American    2054-5        F   219.0    630901.0
# 3                         White    2106-3        F   528.0   1645541.0
# 4     Black or African American    2054-5        F   167.0    633374.0
# ...                         ...       ...      ...     ...         ...
# 1962                      White    2106-3        F    50.0    268767.0
# 1963                      White    2106-3        F    68.0    270054.0
# 1964                      White    2106-3        F    68.0    269349.0
# 1965                      White    2106-3        F    56.0    266963.0
# 1966                      White    2106-3        F    70.0    266262.0
#
#       Age-Adjusted Rate
# 0                  29.7
# 1                  25.9
# 2                  38.7
# 3                  25.8
# 4                  29.2
# ...                 ...
# 1962               14.1
# 1963               19.7
# 1964               20.0
# 1965               16.5
# 1966               20.6
#
# [1853 rows x 10 columns]

# %%
df_white = df_clean[df_clean["Race"]=="White"]
df_white
# Out:
#      Leading Cancer Sites    State  State Code    Year   Race Race Code  \
# 1                  Breast  Alabama         1.0  2000.0  White    2106-3
# 3                  Breast  Alabama         1.0  2001.0  White    2106-3
# 5                  Breast  Alabama         1.0  2002.0  White    2106-3
# 7                  Breast  Alabama         1.0  2003.0  White    2106-3
# 9                  Breast  Alabama         1.0  2004.0  White    2106-3
# ...                   ...      ...         ...     ...    ...       ...
# 1962               Breast  Wyoming        56.0  2014.0  White    2106-3
# 1963               Breast  Wyoming        56.0  2015.0  White    2106-3
# 1964               Breast  Wyoming        56.0  2016.0  White    2106-3
# 1965               Breast  Wyoming        56.0  2017.0  White    2106-3
# 1966               Breast  Wyoming        56.0  2018.0  White    2106-3
#
#      Sex Code  Deaths  Population  Age-Adjusted Rate
# 1           F   524.0   1643761.0               25.9
# 3           F   528.0   1645541.0               25.8
# 5           F   513.0   1646445.0               24.6
# 7           F   484.0   1650890.0               23.2
# 9           F   487.0   1657539.0               23.2
# ...       ...     ...         ...                ...
# 1962        F    50.0    268767.0               14.1
# 1963        F    68.0    270054.0               19.7
# 1964        F    68.0    269349.0               20.0
# 1965        F    56.0    266963.0               16.5
# 1966        F    70.0    266262.0               20.6
#
# [969 rows x 10 columns]

# %%
df_white_clean = df_white.drop(columns=['Leading Cancer Sites','State','State Code','Year', 'Race Code','Sex Code', 'Age-Adjusted Rate' ],axis=1)
df_white_clean
# Out:
#        Race  Deaths  Population
# 1     White   524.0   1643761.0
# 3     White   528.0   1645541.0
# 5     White   513.0   1646445.0
# 7     White   484.0   1650890.0
# 9     White   487.0   1657539.0
# ...     ...     ...         ...
# 1962  White    50.0    268767.0
# 1963  White    68.0    270054.0
# 1964  White    68.0    269349.0
# 1965  White    56.0    266963.0
# 1966  White    70.0    266262.0
#
# [969 rows x 3 columns]

# %%
df_white_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 969 entries, 1 to 1966
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Race        969 non-null    object
#  1   Deaths      969 non-null    float64
#  2   Population  969 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 30.3+ KB

# %%
df_white_clean.dtypes
# Out:
# Race           object
# Deaths        float64
# Population    float64
# dtype: object

# %%
from pathlib import Path
plt.scatter(df_white_clean.Population, df_white_clean.Deaths)
plt.xlabel('Population')
plt.ylabel('Deaths')
plt.show()

# %%
X = df_white_clean.Population.values.reshape(-1, 1)

# %%
X.shape
# Out:
# (969, 1)

# %%
y = df_white_clean.Deaths

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (969,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.00026136]
# 39.63214377775432
