# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random as rnd
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE

# %%
# Import file
file = "Resources/Incident_data.txt"
df = pd.read_csv(file, encoding="ISO-8859-1", sep='\t')
display(df)
# Out:
#                                                   Notes Leading Cancer Sites  \
# 0                                                   NaN               Breast
# 1                                                   NaN               Breast
# 2                                                   NaN               Breast
# 3                                                   NaN               Breast
# 4                                                   NaN               Breast
# ...                                                 ...                  ...
# 3948        standard groupings of primary cancer sites.                  NaN
# 3949  8. For the 2005 year, the Census Bureau estima...                  NaN
# 3950  Texas due to Hurricanes Katrina and Rita. CDC ...                  NaN
# 3951  these states, nor are these counts included in...                  NaN
# 3952  population. However, the USCS web site does in...                  NaN
#
# ...

# %%
# Drop all columns without any information
df_dropped = df.drop(columns=['Notes','Leading Cancer Sites Code','Year Code','Sex' ],axis=1)
df_dropped = df_dropped.dropna(how='any')
display(df_dropped)
# Out:
#      Leading Cancer Sites   States  States Code    Year  \
# 0                  Breast  Alabama          1.0  1999.0
# 1                  Breast  Alabama          1.0  1999.0
# 2                  Breast  Alabama          1.0  1999.0
# 3                  Breast  Alabama          1.0  1999.0
# 4                  Breast  Alabama          1.0  1999.0
# ...                   ...      ...          ...     ...
# 3890               Breast  Wyoming         56.0  2014.0
# 3891               Breast  Wyoming         56.0  2015.0
# 3892               Breast  Wyoming         56.0  2016.0
# 3893               Breast  Wyoming         56.0  2017.0
# 3894               Breast  Wyoming         56.0  2018.0
#
#                                   Race Race Code Sex Code   Count  \
# 0            Asian or Pacific Islander      A-PI        F    18.0
# 1            Black or African American    2054-5        F   597.0
# 2                                White    2106-3        F  2360.0
# ...

# %%
df_no_other_race = df_dropped[df_dropped["Race"]!="Other Races and Unknown combined"]
df_no_other_race
# Out:
#      Leading Cancer Sites   States  States Code    Year  \
# 0                  Breast  Alabama          1.0  1999.0
# 1                  Breast  Alabama          1.0  1999.0
# 2                  Breast  Alabama          1.0  1999.0
# 3                  Breast  Alabama          1.0  1999.0
# 5                  Breast  Alabama          1.0  2000.0
# ...                   ...      ...          ...     ...
# 3890               Breast  Wyoming         56.0  2014.0
# 3891               Breast  Wyoming         56.0  2015.0
# 3892               Breast  Wyoming         56.0  2016.0
# 3893               Breast  Wyoming         56.0  2017.0
# 3894               Breast  Wyoming         56.0  2018.0
#
#                            Race Race Code Sex Code   Count Population
# 0     Asian or Pacific Islander      A-PI        F    18.0      17708
# 1     Black or African American    2054-5        F   597.0     623475
# 2                         White    2106-3        F  2360.0    1640665
# ...

# %%
df_native_am = df_no_other_race[df_no_other_race["Race"]=="American Indian or Alaska Native"]
df_native_am
# Out:
#      Leading Cancer Sites     States  States Code    Year  \
# 85                 Breast     Alaska          2.0  1999.0
# 87                 Breast     Alaska          2.0  2000.0
# 89                 Breast     Alaska          2.0  2001.0
# 91                 Breast     Alaska          2.0  2002.0
# 93                 Breast     Alaska          2.0  2003.0
# ...                   ...        ...          ...     ...
# 3846               Breast  Wisconsin         55.0  2014.0
# 3852               Breast  Wisconsin         55.0  2015.0
# 3858               Breast  Wisconsin         55.0  2016.0
# 3864               Breast  Wisconsin         55.0  2017.0
# 3870               Breast  Wisconsin         55.0  2018.0
#
#                                   Race Race Code Sex Code  Count Population
# 85    American Indian or Alaska Native    1002-5        F   34.0      52608
# 87    American Indian or Alaska Native    1002-5        F   60.0      53700
# ...

# %%
df_native_clean = df_native_am.drop(columns=['Leading Cancer Sites','States','States Code','Year', 'Race Code','Sex Code' ],axis=1)
df_native_clean
# Out:
#                                   Race  Count Population
# 85    American Indian or Alaska Native   34.0      52608
# 87    American Indian or Alaska Native   60.0      53700
# 89    American Indian or Alaska Native   55.0      54065
# 91    American Indian or Alaska Native   51.0      54543
# 93    American Indian or Alaska Native   73.0      55083
# ...                                ...    ...        ...
# 3846  American Indian or Alaska Native   42.0      35998
# 3852  American Indian or Alaska Native   28.0      36449
# 3858  American Indian or Alaska Native   42.0      37052
# 3864  American Indian or Alaska Native   51.0      37681
# 3870  American Indian or Alaska Native   49.0      38099
#
# [326 rows x 3 columns]

# %%
from pathlib import Path
from sklearn.linear_model import LinearRegression

plt.scatter(df_native_clean.Population, df_native_clean.Count)
#plt.xticks([0, 50000, 150000, 250000, 350000, 550000, 750000, 950000])
plt.xlabel('Population')
plt.ylabel('Count')
plt.show()

# %%
df_native_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 326 entries, 85 to 3870
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Race        326 non-null    object
#  1   Count       326 non-null    float64
#  2   Population  326 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 10.2+ KB

# %%
df_native_clean['Population'] = df_native_clean['Population'].astype(float)

# %%
df_native_clean.dtypes
# Out:
# Race           object
# Count         float64
# Population    float64
# dtype: object

# %%
plt.scatter(df_native_clean.Population, df_native_clean.Count)
#plt.xticks([0, 50000, 150000, 250000, 350000, 550000, 750000, 950000])
plt.xlabel('Population')
plt.ylabel('Count')
plt.show()

# %%
X = df_native_clean.Population.values.reshape(-1, 1)

# %%
X.shape
# Out:
# (326, 1)

# %%
y = df_native_clean.Count

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (326,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.00043482]
# 18.946698258743794
