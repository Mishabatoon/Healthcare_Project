# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Import file
file = "Data/Mortality_Rate.txt"
df = pd.read_csv(file, encoding="ISO-8859-1", sep='\t')
display(df)
# Out:
#                                                   Notes Leading Cancer Sites  \
# 0                                                   NaN               Breast
# 1                                                   NaN               Breast
# 2                                                   NaN               Breast
# 3                                                   NaN               Breast
# 4                                                   NaN               Breast
# ...                                                 ...                  ...
# 2016  data set. Death rates may differ slightly from...                  NaN
# 2017  4. For the 2005 year, the Census Bureau estima...                  NaN
# 2018  Texas due to Hurricanes Katrina and Rita. CDC ...                  NaN
# 2019  these states, nor are these counts included in...                  NaN
# 2020  population. However, the USCS web site does in...                  NaN
#
# ...

# %%
# Drop all columns without any information
df_dropped = df.drop(columns=['Notes','Leading Cancer Sites Code', 'Leading Cancer Sites', 'Race Code', 'State Code', 'Year Code' ],axis=1)
df_dropped = df_dropped.dropna(how='any')
display(df_dropped)
# Out:
#         State    Year                       Race     Sex Sex Code  Deaths  \
# 0     Alabama  2000.0  Black or African American  Female        F   166.0
# 1     Alabama  2000.0                      White  Female        F   524.0
# 2     Alabama  2001.0  Black or African American  Female        F   219.0
# 3     Alabama  2001.0                      White  Female        F   528.0
# 4     Alabama  2002.0  Black or African American  Female        F   167.0
# ...       ...     ...                        ...     ...      ...     ...
# 1962  Wyoming  2014.0                      White  Female        F    50.0
# 1963  Wyoming  2015.0                      White  Female        F    68.0
# 1964  Wyoming  2016.0                      White  Female        F    68.0
# 1965  Wyoming  2017.0                      White  Female        F    56.0
# 1966  Wyoming  2018.0                      White  Female        F    70.0
#
#       Population  Age-Adjusted Rate
# 0       627439.0               29.7
# ...

# %%
df_clean_mortality = df_dropped[df_dropped["Race"]!="Other Races and Unknown combined"]
df_clean_mortality
# Out:
#         State    Year                       Race     Sex Sex Code  Deaths  \
# 0     Alabama  2000.0  Black or African American  Female        F   166.0
# 1     Alabama  2000.0                      White  Female        F   524.0
# 2     Alabama  2001.0  Black or African American  Female        F   219.0
# 3     Alabama  2001.0                      White  Female        F   528.0
# 4     Alabama  2002.0  Black or African American  Female        F   167.0
# ...       ...     ...                        ...     ...      ...     ...
# 1962  Wyoming  2014.0                      White  Female        F    50.0
# 1963  Wyoming  2015.0                      White  Female        F    68.0
# 1964  Wyoming  2016.0                      White  Female        F    68.0
# 1965  Wyoming  2017.0                      White  Female        F    56.0
# 1966  Wyoming  2018.0                      White  Female        F    70.0
#
#       Population  Age-Adjusted Rate
# 0       627439.0               29.7
# ...

# %%
df_clean_mortality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1967 entries, 0 to 1966
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              1967 non-null   object
#  1   Year               1967 non-null   float64
#  2   Race               1967 non-null   object
#  3   Sex                1967 non-null   object
#  4   Sex Code           1967 non-null   object
#  5   Deaths             1967 non-null   float64
#  6   Population         1967 non-null   float64
#  7   Age-Adjusted Rate  1967 non-null   float64
# dtypes: float64(4), object(4)
# memory usage: 138.3+ KB

# %%
df_clean_mortality['Race'].unique()
# Out:
# array(['Black or African American', 'White',
#        'American Indian or Alaska Native', 'Asian or Pacific Islander'],
#       dtype=object)

# %%
df_clean_mortality.dtypes
# Out:
# State                 object
# Year                 float64
# Race                  object
# Sex                   object
# Sex Code              object
# Deaths               float64
# Population           float64
# Age-Adjusted Rate    float64
# dtype: object

# %%
df_clean_mortality = df_clean_mortality.to_csv("Resources/Final_Clean_Data_Mortality.xlsx")
